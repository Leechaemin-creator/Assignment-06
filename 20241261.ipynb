# %% [markdown]
# 이진 검색 트리 연습문제

# %% [markdown]
# 01. 다음 이진 검색 트리에 대해 답하시오.
# - 이 이진 검색 트리의 리프 노드는 총 몇개인가?
#
# 답: 리프 노드는 자식 노드가 없는 노드를 말한다. 따라서 다음 이진 검색 트리의 리프 노드는 7, 17, 70으로 총 3개 이다.
#
# - 현재 높이 4를 유지하면서 키를 추가한다면 가능한 리프 노드의 최대 개수는 몇개인가?
#
# 답: 리프 노드의 개수를 최대로 하려면, 높이 4 범위 내에서 모든 가지가 끝까지 뻗어 나가는 포화이진트리 형태를 만들면 되므로 가능한 리프노드의 개수는 최대 8개이다.
#
# - 높이 4인 이진 검색 트리가 포화 이진 트리 모양이 되면 리프 노드와 리프 노드를 제외한 나머지 노드의 수는 몇 개나 차이가 나는가?
#
# 답: 높이가 4인 포화 이진 트리의 전체 노드의 수는 15개이고, 리프 노드의 수는 8개 이므로 내부노드의 개수는 15-8=7개 이다. 따라서 리프노드와 내부노드 개수의 차이는 1개이다.
#
# - 위 3의 성질은 높이가 h인 모든 포화 이진 트리에 대해 성립하는가?
#
# 답: 높이 h에 상관없이 모든 포화 이진트리에서 리프 노드의 개수는 항상 내부 노드의 개수보다 1개 더 많다.

# %% [markdown]
# 2. 임의의 완전 이진 트리에 대한 다음 물음에 답하시오.
# - 트리의 총 노드 수가 n이면 리프 노드의 수는 몇 개인가?
#
# 답: 이진 트리에서는 한 노드가 최대 2개의 자식을 가진다. 따라서 전체 노드의 약 절반 정도가 마지막 레벨이나 그 바로 위 레벨에서 리프 노드가 된다. 따라서 리프 노드의 개수는 n/2개 또는 (n+1)/2개 이다.
#
# - 위 1에서 리프 노드의 수와 내부 노드의 수는 어떤 관계인가?
#
# 답: 포화 이진 트리 이거나 전체 노드의 개수가 홀수개인 경우, 리프 노드의 수는 내부 노드의 수보다 1개 더 많다. 그리고 전체 노드의 개수가 짝수개인 경우, 리프 노드의 수와 내부 노드의 수는 같다. 따라서 완전 이진 트리에서 리프 노드의 수는 내부 노드의 수와 같거나 1게 더 많다.

# %%
3. 다음 이진 검색 트리에 대해 답하시오.
- 이 검색 트리를 전위 순회 방식으로 순회할 때 노드의 방문 순서를 나열하시오.

답: 전위 순회 방식의 규칙은 루트 -> 왼쪽자식 -> 오른쪽 자식이므로 방문 순서는 5 - 3 - 1 - 8 - 7 - 6 - 9 이다.

- 이 검색 트리를 중위 순회 방식으로 순회할 때 노드의 방문 순서를 나열하시오.

답: 중위 순회 방식의 규칙은 왼쪽자식 -> 루트 -> 오른쪽 자식이므로 방문 순서는 1 - 3 - 5 - 6 - 7 - 8 - 9 이다.

- 이 검색 트리를 후위 순회 방식으로 순회할 때 노드의 방문 순서를 나열하시오.

답: 후위 순회 방식의 규칙은 왼쪽 자식 -> 오른쪽 자식 -> 루트 이므로 방문 순서는 1 - 3 - 6 - 7 - 9 - 8 - 5 이다.

- 중위 순회는 모든 이진 검색 트리에 대해 항상 키를 정렬된 순서로 방문한다는 사실을 증명하시오.

답: 트리의 구조를 살펴보면 왼쪽 서브트리는 이미 작은 값들이고, 루트는 그보다 큰 값, 오른쪽 서브트리는 더 큰 값들이다. 이를 바탕으로 중위 순회 방식을 살펴보면 (작은 값들) -> 루트 -> (큰 값들) 이 구조가 계속해서 반복된다. 따라서 중위 순회 결과는 항상 오름차순 정렬된 값이 된다.

# %% [markdown]
# 4. 다음 이진 검색 트리에서 키 30을 검색하는 과정을 순서대로 설명하시오.
#
# 답 : 이진 검색 트리의 규칙은 루트 노드보다 작은 값들은 왼쪽 서브트리에, 루트 노드보다 큰 값들은 오른쪽 서브트리에 위치한다. 루트 노드부터 차례로 살펴보면
# 30 < 55 이므로 왼쪽 이동, 30 > 15 이므로 오른쪽 이동, 30 > 28 이므로 오른쪽 이동하면 30을 검색할 수 있다.

# %% [markdown]
# 5. 4번 문제에 이진 검색 트리에서 키 16이 삽입된 후의 모양을 그리시오.
#
# ![문제5.png](attachment:문제5.png)

# %% [markdown]
# 6. 다음 이진 검색 트리에서 키 38을 삭제한 후의 모양을 그리시오.
#
#
# ![스크린샷 2026-04-21 122355.png](<attachment:스크린샷 2026-04-21 122355.png>)

# %% [markdown]
# 7. 6번 문제에서 주어진 이진 검색 트리에서 키 3을 삭제한 후의 모양을 그리시오.
#
# ![alt text](<스크린샷 2026-04-21 122520.png>)

# %% [markdown]
# 8. 6번 문제에서 주어진 이진 검색 트리에서 키 15를 삭제한 후의 모양을 그리시오.
#
#
# ![alt text](<스크린샷 2026-04-21 122603.png>)

# %% [markdown]
# 9. n개의 원소로 구성되는 이진 검색 트리의 가능한 최대 높이와 최소 높이는 어떻게 되는가?
#
# 답 : 트리의 높이가 최대가 될 때는 노드들이 일렬로 연결된 경우이므로 최대 높이는 n이다. 트리의 높이가 최소가 될 때는 왼전 이진 트리인 경우이므로 최소 높이는 lgn+1 개 이다.
